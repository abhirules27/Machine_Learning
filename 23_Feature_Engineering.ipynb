# %% [markdown]
# <a href="https://colab.research.google.com/github/abhirules27/Machine_Learning/blob/From_Google_Colab/23_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# It’s the process of turning raw data into useful inputs (“features”) that help a model learn better.
# Why it matters: Better features → simpler models, higher accuracy, faster training.

# Typical steps
# 1. Clean & type-cast: fix missing values, correct types (dates, categories).
# 2. Create features: ratios, differences, counts, rolling stats, domain rules.
# 3. Transform: scale/normalize, log/sqrt, binning, one-hot/target encoding.
# 4. Extract from text/time: TF-IDF, embeddings; year/month/day, time since event.
# 5. Reduce/Select: remove leakage, drop multicollinearity, PCA, mutual info, model-based importance.

# %%
# Feature Engineering nicludes

# A. Feature Transformation: Missing Value Imputation, Handling cat Features, Outlier Deteaction, Feature Scaling
# B. Feature Construction:
# C. Feature Selection:
# D. Feature Extraction:

# %%
# A. Feature Transformation

# A1. Missing Values -> To be filled or removed
# How to fill -> Fill by mean, median, max occuring value, etc
# When to remove -> When missing data is very less

# %%
# A2. Handling Categorical Values

# %%
# A3. Outlier Detection

# %%
# A4. Feature Scaling -> Generally -1 to 1

# %%
# B. Feature Construction

# %%
# C. Feature Selection

# MNIST Dataset -> Hand writtend dataset showing digits (28x28 resolution)

# %%
# D. Feature Extraction

# New features are created using existing features programatically
